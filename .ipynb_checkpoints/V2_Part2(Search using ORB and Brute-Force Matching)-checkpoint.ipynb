# %%
import numpy as np
import cv2
import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
image=cv2.imread('aa.png')
image2=cv2.imread('dd.png')
cv2.imshow("Query Image",image)
cv2.imshow('Traing Image',image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2GRAY)

# %%
orb=cv2.ORB_create()
kp1,descriptor1=orb.detectAndCompute(image1,None)
kp2,descriptor2=orb.detectAndCompute(image2,None)
print('image1 Keypoints : ',len(kp1))
print('image2 keypoints : ',len(kp2))
# Out:
# image1 Keypoints :  460
# image2 keypoints :  500

# %%
Matcher=cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)
matches=Matcher.match(descriptor1,descriptor2)
matches=sorted(matches,key=lambda x:x.distance)
print(len(matches))
#for m in matches:
#    print(m.distance)
image3=cv2.drawMatches(image1,kp1,image2,kp2,matches[:50],None,flags=2)
fig=plt.figure(figsize=(15,15))
plt.imshow(image3)
plt.show()
#cv2.imshow('result',image3)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# 146

# %%
results={}
Matcher=cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)
for des_path in glob.glob('Descriptors/*'):
    sum=0
    ImageID=des_path[des_path.rfind("\\")+1:].split('.')[0]
    desriptor=np.load(des_path)
    matches=Matcher.match(descriptor1,desriptor)
    matches=sorted(matches,key=lambda x:x.distance)
    for i in range(50):
        sum+=matches[i].distance
    sum=sum/50
    results[ImageID]=sum
results=sorted([(v,k) for (k,v) in results.items()])

# %%
for (v,k) in results:
    print('ID :',k)
    print('V :',v)
# Out:
# ID : homepage2niftycomhosonumabicyclepantanitdfIMG12741
# V : 1.42
# ID : wwwrivendellbicyclescomimagesbikesmainatlantis2
# V : 52.78
# ID : yfieldcomveralucbicycle2desert
# V : 56.46
# ID : wwwdowntheroadorgimagesPhoto20AlbumNewFolder11DSC00089
# V : 56.92
# ID : wwwunclepashacommoscowaccommodationdutchloftbicyclesmm
# V : 56.94
# ID : visualizationtudelftnlariweblogfietsactie1
# V : 57.86
# ID : homewangjianshuocomphotochongmingslidesshanghaibicyclestartingvanke
# V : 58.02
# ID : wwwbalanceforlifecomimagescontenthealthtipsbicyclemain
# V : 58.04
# ID : wwwbikeiconscomimages189720Columbus20Bicycle20Co20Girls
# V : 58.12
# ID : wwwworldshop1comchinedirectimagesbicyclesPL26E88E20Electric20Bicycle
# V : 58.18
# ID : wwwtotalbikecomgalleryimages18
# V : 58.46
# ID : wwwmomovelocomimagescheesecheese3760
# V : 58.62
# ID : wwwlpdssztakihurobertophotosGreece98bicycle
# V : 58.68
# ID : wwwbrucedalecomChina20PhotosNorthwest20Chinabicycle
# V : 58.74
# ID : wwwmunsonbuilderscomSouthportPhotosman20on20bicycle20by20fingelly20real20estate
# V : 58.82
# ID : wwwyasukawacommamiarchivesimagesbicycle0429
# V : 58.86
# ID : todaibicyclemainjpphotohrRIMG00101
# V : 58.96
# ID : wwwgoldwingworldcomSpringer205
# V : 59.02
# ID : wwwairliecomimages2bicycle
# V : 59.1
# ID : osinftudresdendenf2mexico2003bicycle
# V : 59.12
# ID : wwwdotwisconsingovsafetyvehicleimagesbikecarsredsignal2
# V : 59.16
# ID : wwwgeocitiescomgregu10Bicycle
# V : 59.28
# ID : wwwabbikecomgraphicsMiscRiders4
# V : 59.34
# ID : wwwmtcntnuedutwdragonboatdb02jackimagesDayAfterSatoshionBicycle
# V : 59.42
# ID : kaiyacsshinshuuacjpkaiyabicycle2003fukushimaimga01112600
# V : 59.46
# ID : ttitamueduresearcherv39n3imagesbicycle
# V : 59.46
# ID : wwwcoaraorjpmykmpkzbicycle
# V : 59.64
# ID : wwwhutsorgimagesactivitiespeoplebicyclecroppedweb
# V : 59.76
# ID : wwwjwoodandcompanycom2004daytonaTriumphbicycle
# V : 59.78
# ID : wwwcheltenhamgovuklibrariesimagesthefuturedraft20transport20planbicycle
# V : 59.84
# ID : wwwsinitscomphotoseuropedunkerquebicycle
# V : 59.92
# ID : wwwfremontohspeedwaycombicycle
# V : 59.96
# ID : wwwcityoforovilleorgPolicePD20PIC27SBicycle
# V : 60.04
# ID : wwwbicyclestuffcomstuffforsalepicsRebecca20bike2
# V : 60.06
# ID : wwwgatlinburgtennesseecompresskitimagesbicycle
# V : 60.24
# ID : mcduffiemirrorcomimagesheadlines06170413985512
# V : 60.46
# ID : wwwbjorgenetpictripbike
# V : 60.46
# ID : wwwsheldonbrownorgracingamericancup431
# V : 60.46
# ID : wwwbeevillenetBicycleclassic2004PhotosBeevilleBeeCountyHTEBicycleClassic2004P7106564small
# V : 60.48
# ID : wwwchandlerpdcomcpdsiteDarePDKidsDAREVehiclesContentPagesallterrainbicycle
# V : 60.48
# ID : wwwaea1k12iausnwinnPictures2020032004Bicycle20RodeoBicycle20RodeoImages9
# V : 60.5
# ID : wwwumicheduurecord0405Sept0704img040907dearbornbike
# V : 60.52
# ID : wwwbeautifullandscapecomNew20SitedataPrints20of20the20monthBicycle500
# V : 60.54
# ID : wwwbathacuksocpolimagesstonesandbicyclesept2003
# V : 60.62
# ID : wwwcsbhamacukjerphotoslofotensbicycle
# V : 60.68
# ID : wwwbakeruedutechimagesPhotoswebbicycle
# V : 60.7
# ID : wwweducanetchhomefeelthewindsamosDateienimage004
# V : 60.74
# ID : wwwbreezerbikescomstreet3
# V : 60.78
# ID : www8plalaorjpematsukaimagesbicycleDSC01512
# V : 61.0
# ID : wwwgcmaricopaedubusinesschinajune4Man20with20Bicycle
# V : 61.08
# ID : wwwjsdiorjpytomtopgallerybicycle
# V : 61.12
# ID : wwwexperiencepluscomimagesemaildsc0040
# V : 61.14
# ID : wwwcamocladcomimagesbicyclemob
# V : 61.16
# ID : branchburgnewspapertripodcomjan20editionjan20picsbicycle
# V : 61.18
# ID : photos1bloggercomimg1741145320BLUE20BICYCLE20IAG
# V : 61.22
# ID : userscwnetcombrilleroriginaldbwbike2
# V : 61.22
# ID : wwwjadedtinejpchubicyclemybikeindexfilesbd1gazomiyata26
# V : 61.34
# ID : wwwflickrcomphotos3310203236535340N00
# V : 61.4
# ID : wwwacmebicyclecompanycomimagessmmine03
# V : 61.5
# ID : wwwexclamationsandiegohotelreservationscompictureforsandiegoBicycleToursB
# V : 61.58
# ID : wwwegguevaracommadisongrowingbicycle
# V : 61.7
# ID : www95xnetimagesbicycle20rodeo1
# V : 61.74
# ID : wwwdobradesigncompiphotogallerypischools
# V : 62.12
# ID : wwwibizaselectcomimagesbarribicycle
# V : 62.16
# ID : wwwcityvancouverbccapoliceBicyclebike4a
# V : 62.46
# ID : takachinoipcomcycletouringbicyclebrake2927
# V : 62.62
# ID : imagesfbrtechcomalbumsbicyclebike13sized
# V : 62.66
# ID : wwwbigbearcabinsfrcomphotosbicycle
# V : 62.72
# ID : wwwreddirtpedalerscomBicycle20Picture20ArchiveWesbikeWesbike1
# V : 62.82
# ID : uwajuncocologniftycomurouroimgbicycle
# V : 62.98
# ID : wwwreddirtpedalerscomBicycle20Picture20ArchiveMarybike
# V : 63.04
# ID : wwwmontanaeduwwwmsupdimagesbikereg
# V : 63.16
# ID : wwwbikemotorcomimagesMariner20Encore20folding20bicycle
# V : 63.26
# ID : watsennetkentbicycle
# V : 63.5
# ID : wwwexclamationsandiegohotelreservationscompictureforsandiegoBicycleTours2B
# V : 63.68
# ID : wwwukstudentlifecomTravelTransportBicycleCyclists
# V : 63.7
# ID : wwwwisilrecumbentscomwisilracing2003floridaflorida2003RonKauffmanTTstartsm
# V : 63.74
# ID : wwwbiriacomimagesbiriacover
# V : 63.82
# ID : hometiscalinltaudinCommonimageImagebankAmsterdamstreetcanalsOriginalsizebicycle
# V : 64.06
# ID : wwwlrghorgimagesauctionimgsBicycle
# V : 64.06
# ID : wwwfcjapancojpkentaweeklyimagesbicycle
# V : 64.36
# ID : wwwmolokaioutdoorscomgraphicshalawabicyclegirls
# V : 64.76
# ID : wwwarientercommorigifbicycle
# V : 64.8
# ID : membersaolcombrownebicycle
# V : 65.96
# ID : wwwfredmirandacomhostingdata50132827bluebicyclefm
# V : 66.6

# %%
type(results)
# Out:
# list

# %%
r1=cv2.imread('bicycle/'+results[0][1]+'.png')
r2=cv2.imread('bicycle/'+results[1][1]+'.png')
r3=cv2.imread('bicycle/'+results[2][1]+'.png')
r4=cv2.imread('bicycle/'+results[3][1]+'.png')
cv2.imshow('Query Image',image)
cv2.imshow('R1',r1)
cv2.imshow('R2',r2)
cv2.imshow('R3',r3)
cv2.imshow('R4',r4)
cv2.waitKey(0)
cv2.destroyAllWindows()
